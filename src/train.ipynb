# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd './drive/My Drive/pong/src'
# Out:
# [Errno 2] No such file or directory: './drive/My Drive/pong/src'
# /content/drive/My Drive/pong/src

# %%
# !python train.py
# Out:
# ...
# Update 751: Episode 1/15, Reward = -7
# Update 751: Episode 2/15, Reward = -11
# Update 751: Episode 3/15, Reward = -11
# Update 751: Episode 4/15, Reward = -6
# Update 751: Episode 5/15, Reward = -13
# Update 751: Episode 6/15, Reward = -12
# Update 751: Episode 7/15, Reward = -11
# Update 751: Episode 8/15, Reward = -15
# Update 751: Episode 9/15, Reward = -8
# Update 751: Episode 10/15, Reward = -6
# Update 751: Episode 11/15, Reward = -3
# Update 751: Episode 12/15, Reward = -9
# Update 751: Episode 13/15, Reward = -2
# Update 751: Episode 14/15, Reward = -13
# Update 751: Episode 15/15, Reward = -9
# Start training with 93892 data...Done
# Update 751: Average reward = -9.07
#
# ...
# Update 752: Episode 1/15, Reward = -10
# Update 752: Episode 2/15, Reward = -9
# Update 752: Episode 3/15, Reward = -13
# Update 752: Episode 4/15, Reward = -7
# Update 752: Episode 5/15, Reward = -11
# Update 752: Episode 6/15, Reward = -11
# Update 752: Episode 7/15, Reward = -9
# ...
